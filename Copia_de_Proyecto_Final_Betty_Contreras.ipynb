# %% [markdown]
# <a href="https://colab.research.google.com/github/BETY201/proyectos/blob/main/Copia_de_Proyecto_Final_Betty_Contreras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #**PROYECTO FINAL DEL CURSO DE CIENCIAS DE DATOS GRUPO4**
# ### **Elaborado Por: Betty Contreras Campo**
# ---
#
#
#
# **Titulo: INCIDENCIA DE FACTORES EXTERNOS EN EL RENDIMIENTO ACADÉMICO DE ESTUDIANTES DE GRADOS DÉCIMO Y UNDÉCIMO EN LA INSTITUCIÓN EDUCATIVA TECNICA EN INFORMATICA DE SINCELEJITO EN ÁREAS COMO CIENCIAS NATURALES  Y EDUCACION AMBIENTAL**
#
#
# **Motivación: Estamos interesados en indagar  factores externos como desayunar y dormir bien inciden en el rendimiento académino de los estudiantes de grados superiores en algunas áreas tales como las Ciencias Naturales y Educacion Ambiental**
#
# **Objetivo general: Hacer un analisis la incidencia que pueden tener factores externos, en el rendimiento académico de estudiantes de grado décimo y undécimo**
#
# **Objetivos específicos:
#
# 1. Realizar un analisis descriptivo de todas las variables cuantitativas mediante gráficos de boxplot, observar su distribución mediante histogramas y obtener las medidas de tendencia central, dispersión y posición para los datos individuales y datos agrupados para realizar conclusiones evidentes en los gráficos.
#
# 2.  Realizar un analisis descriptivo de todas las variables cualitativas con graficos de barras univariados y bivariados y observar el comportamiento entre ellas para realizar conclusiones evidentes en los gráficos.
#
# 3. Analizar relaciones bivariadas entre dos variables para establecer la influencia de unas variables sobre otras. Así: (a) Entre dos variables cualitativas, (b) Entre una variable cualitativa y una cuantitativa y (c) entre dos cuantitativas.
#
# 3. Realizar gráficos de Splot para verificar la relación entre el desayuno y descanso y las notas definitivas de los tres periodos académicos. Igualmente, hacer gráficos para establecer la relación entre el medio de transporte y la asistencia a clases de los estudiantes
#
# 4. Establecer conclusiones observables en cada analisis estadístico realizado con los datos base de estudio y plantear posibles soluciones.

# %% [markdown]
# ---
#
#
# ## **DESARROLLO DEL PROYECTO**

# %% [markdown]
# # **Estadistica Descriptiva**

# %% [markdown]
# **0. Revisar el contenido del DataFrame y observar si faltan datos**

# %%
# @title **librerias usadas**
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# @title **Importamos los datos desde el archivo DATOS_ESTUDIANTES_IESC.csv y lo asignamos a la variable df**
df = pd.read_csv("/content/DATOS_ESTUDIANTES_INETIS.csv", delimiter=';')
df
# Out:
#      CURSO  ASISTENCIA DEFINITIVA_1P DEFINITIVA_2P DEFINITIVA_3P  \
# 0   DECIMO          50           3,6           4,3           3,6
# 1     ONCE          70           1,5           2,5           2.3
# 2   DECIMO          85           3,9           3,8           3,9
# 3   DECIMO          50           2,9           0,5           2,9
# 4     ONCE          20           3,7          0,55           3,7
# ..     ...         ...           ...           ...           ...
# 69    ONCE          90           2,3           2,1           2,3
# 70  DECIMO          85           3,6           3,1           2,5
# 71  DECIMO          65           1,7          2,95           1,7
# 72  DECIMO         100           2,3           3,2           2,3
# 73  DECIMO          60           3,8           3,1           3,8
#
#    DEFINITIVA_4P         AREA  EDAD       SEXO TRANSPORTE COME BIEN  \
# 0           4,15  C_NATURALES    15   Femenino   MOTOTAXI        SI
# ...

# %%
# @title **Cantidad de estudiantes y variables**
No_estudiantes_y_Variables = df.shape
print('(No estudiantes, No Variables) = ',No_estudiantes_y_Variables)
# Out:
# (No estudiantes, No Variables) =  (74, 12)

# %%
# @title **Mostrar información del tipo de las  variables y registros nulos (null)**
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CURSO          74 non-null     object
#  1   ASISTENCIA     74 non-null     int64
#  2   DEFINITIVA_1P  74 non-null     object
#  3   DEFINITIVA_2P  74 non-null     object
#  4   DEFINITIVA_3P  74 non-null     object
#  5   DEFINITIVA_4P  74 non-null     object
#  6   AREA           74 non-null     object
#  7   EDAD           74 non-null     int64
#  8   SEXO           74 non-null     object
#  9   TRANSPORTE     74 non-null     object
#  10  COME BIEN      74 non-null     object
#  11  DUERME BIEN    74 non-null     object
# dtypes: int64(2), object(10)
# memory usage: 7.1+ KB

# %%
# @title **Mostrar los diferentes tipos de cursos**
Tipos_cursos = df['CURSO'].unique()
print('Cursos=', Tipos_cursos)
# Out:
# Cursos= ['DECIMO' 'ONCE']

# %%
# @title **Mostrar las diferentes áreas de estudio**
Tipos_areas = df['AREA'].unique()
print('Areas=',Tipos_areas )
# Out:
# Areas= ['C_NATURALES' 'E_AMBIENTAL']

# %%
# @title **Mostrar los diferentes tipos de transporte**
Tipos_transportes= df['TRANSPORTE'].unique()
print('Transporte=', Tipos_transportes)
# Out:
# Transporte= ['MOTOTAXI' 'CAMINANDO' 'CARRO']

# %%
# @title **Mostrar información del tipo de las  variables y registros nulos (null)**
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CURSO          74 non-null     object
#  1   ASISTENCIA     74 non-null     int64
#  2   DEFINITIVA_1P  74 non-null     object
#  3   DEFINITIVA_2P  74 non-null     object
#  4   DEFINITIVA_3P  74 non-null     object
#  5   DEFINITIVA_4P  74 non-null     object
#  6   AREA           74 non-null     object
#  7   EDAD           74 non-null     int64
#  8   SEXO           74 non-null     object
#  9   TRANSPORTE     74 non-null     object
#  10  COME BIEN      74 non-null     object
#  11  DUERME BIEN    74 non-null     object
# dtypes: int64(2), object(10)
# memory usage: 7.1+ KB

# %%
#  @title **Muéstrame la posición en transporte con "nan"**

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# ... (Your existing code) ...


# @title **Mostrar la posición de los estudiantes con "nan" en transporte**
nan_transporte_positions = df[df['TRANSPORTE'].isnull()].index.tolist()
print("Posiciones de estudiantes con 'nan' en Transporte:", nan_transporte_positions)
# Out:
# Posiciones de estudiantes con 'nan' en Transporte: []

# %%
# @title **Mostrar los diferentes tipos de transporte**
Tipos_transporte = df['TRANSPORTE'].unique()
print('Transporte = ', Tipos_transporte)
# Out:
# Transporte =  ['MOTOTAXI' 'CAMINANDO' 'CARRO']

# %%
# @title **Mostrar los diferentes tipos de sexo**
Tipos_sexo = df['SEXO'].unique()
print('Sexo=', Tipos_sexo)
# Out:
# Sexo= ['Femenino' 'Masculino']

# %%
# @title **Verificar la cantidad de datos faltantes en cada columna**
faltantes = df.isnull().sum()
faltantes
# Out:
# CURSO            0
# ASISTENCIA       0
# DEFINITIVA_1P    0
# DEFINITIVA_2P    0
# DEFINITIVA_3P    0
# DEFINITIVA_4P    0
# AREA             0
# EDAD             0
# SEXO             0
# TRANSPORTE       0
# COME BIEN        0
# DUERME BIEN      0
# dtype: int64

# %% [markdown]
# # **Analisis**: _Una exploración inicial muestran que:_
#
# * Los datos corresponden a 74 estudiantes con información de **26 caracteristicas**:
#
#   CURSO, ÁREA, ASISTENCIA, NOTAS DEFINITIVAS, EDAD, SEXO, TRANSPORTE, SEXO, SI COME BIEN, SI DUERME BIEN.
#
# * Los estudiantes pertenecen a **2 cursos**:
#
#   DÉCIMO y UNDÉCIMO.
#
# * Existen **2 áreas** a cuyos estudisntes se les hizo la encuesta
#
#   'CIENCIAS NATURALES', 'EDUCACION AMBIENTAL'.
#
# * Los estudiantes llegan a la institución en **3 medios de transporte** diferentes:
#
#   'Mototaxi', 'Caminando', 'Carro'.
#
# *Los estudiantes se identificaron con dos tipos de sexo diferentes
#
# 'Masculino', 'Femenino'.
#
# * No hay datos faltantes (null).

# %% [markdown]
# # **1. Estadísticas Descriptivas (Variables Numéricas):**

# %%
# @title **Estadísticas descriptivas generales**
stats_descriptivas = df.describe()
# Mostrar estadísticas descriptivas
stats_descriptivas
# Out:
#        ASISTENCIA       EDAD
# count   74.000000  74.000000
# mean    84.527027  15.702703
# std     17.244593   0.855758
# min     20.000000  15.000000
# 25%     76.250000  15.000000
# 50%     90.000000  16.000000
# 75%    100.000000  16.000000
# max    100.000000  20.000000

# %% [markdown]
# **Resultado**
#
# | Variable    | Media | Desviación estándar | Mínimo | 25% (Q1) | Mediana (Q2) | 75% (Q3) | Máximo |
# |-------------|-------|---------------------|--------|----------|--------------|----------|--------|
# | Asistencia  | 51.78 | 9.41                | 25     | 45       | 55           | 60       | 60     |
# | Edad        | 18.75 | 1.29                | 17     | 18       | 18           | 19       | 23     |
# |
# **Análisis:**
#
# - **Asistencia:** La asistencia tiene un valor medio de aproximadamente 52 con una desviación estándar de 9.4, lo que indica que la mayoría de los estudiantes tienen una asistencia bastante consistente, cercana al 60%.
# - **Edad:** La mayoría de los estudiantes tiene entre 18 y 19 años. Esto es coherente con el rango de edades típico para estudiantes universitarios.

# %% [markdown]
# ### 2. **Estadísticas Descriptivas (Variables Categóricas):**

# %%
# Estadísticas para variables categóricas
categ_stats = df[['CURSO', 'AREA', 'SEXO', 'TRANSPORTE', 'COME BIEN', 'DUERME BIEN']].describe()

# Mostrar estadísticas descriptivas
categ_stats
# Out:
#        CURSO         AREA      SEXO TRANSPORTE COME BIEN DUERME BIEN
# count     74           74        74         74        74          74
# unique     2            2         2          3         2           2
# top     ONCE  E_AMBIENTAL  Femenino      CARRO        SI          SI
# freq      40           40        42         34        42          42

# %% [markdown]
# **Análisis**
# - **Transporte:** La mayoría de los estudiantes llegan "A pie" a la institución (65).
# - **Sexo:** Hay una mayor proporción de estudiantes femeninos (42 de 74)recuente.
# **Desayuno y descanso:** La mayoría de los estudiantes desayuna (51) y muchos duermen bien, sin embargo, se observa que unos 23 estudiantes no desayunan y unos 30 no duermen bien. Esto es preocupante.

# %% [markdown]
# # **3. Descripción de la distribución de algunas variables (Definitivas, Come bien, Duerme bien)**

# %%
df
# Out:
#      CURSO  ASISTENCIA DEFINITIVA_1P DEFINITIVA_2P DEFINITIVA_3P  \
# 0   DECIMO          50           3,6           4,3           3,6
# 1     ONCE          70           1,5           2,5           2.3
# 2   DECIMO          85           3,9           3,8           3,9
# 3   DECIMO          50           2,9           0,5           2,9
# 4     ONCE          20           3,7          0,55           3,7
# ..     ...         ...           ...           ...           ...
# 69    ONCE          90           2,3           2,1           2,3
# 70  DECIMO          85           3,6           3,1           2,5
# 71  DECIMO          65           1,7          2,95           1,7
# 72  DECIMO         100           2,3           3,2           2,3
# 73  DECIMO          60           3,8           3,1           3,8
#
#    DEFINITIVA_4P         AREA  EDAD       SEXO TRANSPORTE COME BIEN  \
# 0           4,15  C_NATURALES    15   Femenino   MOTOTAXI        SI
# ...

# %%
# Boxplot Edad
plt.subplot(2, 3, 1)
sns.boxplot(data=df, x='EDAD', color='brown')
plt.xlabel('Edad (Años)')
#plt.title('Distribución de Notas Definitivas 1P')



# Histograma de Asistencia
plt.subplot(2, 3, 2)
plt.hist(df['ASISTENCIA'], bins=10, color='blue')
#plt.title('Distribución de Asistencia')
plt.ylabel('Frecuencia')
#plt.xlabel('Asistencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#--aquí realiza las graficas
# @title **Gráficas BoxPlot e Histograma**
plt.figure(figsize=(25, 8))


# Histograma DEFINITIVA DE PRIMER PERIODO
plt.subplot(2, 3, 1)
plt.hist(df['DEFINITIVA_1P'], bins=10, color='skyblue')
#plt.title('Distribución de las Definitivas 1P')
#plt.xlabel('Definitiva (0->5)')
plt.ylabel('Frecuencia')
#plt.xlabel('Definitiva_1p')

# Histograma DEFINITIVA DE SEGUNDO PERIODO
plt.subplot(2, 3, 2)
plt.hist(df['DEFINITIVA_2P'], bins=10, color='yellow')
#plt.title('Distribución de las Definitivas 2P')
#plt.xlabel('Definitiva (0->10)')
plt.ylabel('Frecuencia')
#plt.xlabel('Definitiva_2p')


# Histograma DEFINITIVA DE TERCER PERIODO
plt.subplot(2, 3, 3)
plt.hist(df['DEFINITIVA_3P'], bins=10, color='red')
#plt.title('Distribución de las Definitivas 1P')
#plt.xlabel('Definitiva (0->10)')
plt.ylabel('Frecuencia')
#plt.xlabel('Definitiva_3p')

# Histograma DEFINITIVA DE CUARTO PERIODO
plt.subplot(2, 3, 4)
plt.hist(df['DEFINITIVA_4P'], bins=10, color='brown')
#plt.title('Distribución de las Definitivas 1P')
#plt.xlabel('Definitiva (0->10)')
plt.ylabel('Frecuencia')
#plt.xlabel('Definitiva_4p')

# Histograma de la ASISTENCIA
plt.subplot(2, 3, 5)
plt.hist(df['ASISTENCIA'], bins=10, color='purple')
#plt.title('Distribución de Asistencia')
plt.ylabel('Frecuencia')
#plt.xlabel('Asistencia')


#ajustar espaciado entre subplot
plt.tight_layout()
plt.show()

# %%
# Boxplot Edad
plt.subplot(2, 3, 1)
sns.boxplot(data=df, x='EDAD', color='lightgreen')
plt.xlabel('Edad (Años)')
#plt.title('Distribución de Notas Definitivas 1P')

# Histograma de Asistencia
plt.subplot(2, 3, 2)
plt.hist(df['ASISTENCIA'], bins=10, color='purple')
#plt.title('Distribución de Asistencia')
plt.ylabel('Frecuencia')
#plt.xlabel('Asistencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# **Análisis**
#
# - **Distribución de Notas Definitivas:** Se puede observar un sesgo positivo, con la mayoría de las notas concentradas entre 6 y 9, pero algunos estudiantes tienen notas  bajas.
# - **Distribución de Edad:** La mayoría de los estudiantes tiene entre 15 y 17 años, como se observa en la gráfica, con una distribución muy centrada en esos valores.
# **Distribución de Asistencia:** La mayoría de los estudiantes registran una asistecia entre 60 y 80 veces en cada área.
# -
#
# ### Conclusión:
#  La variable edad tiene una distribución relativamente consistente. Son pocos los estudiantes que han alcanzado la mayoría de edad y la asistencia es relativamente buena.

# %%
#--aquí realiza las graficas
# @title **Gráficas BoxPlot e Histograma**
plt.figure(figsize=(25, 8))

# Histograma DEFINITIVA DE PRIMER PERIODO
plt.subplot(2, 3, 1)
plt.hist(df['DEFINITIVA_1P'], bins=10, color='skyblue')
#plt.title('Distribución de las Definitivas 1P')
#plt.xlabel('Definitiva (0->10)')
plt.ylabel('Frecuencia')

# Histograma DEFINITIVA DE SEGUNDO PERIODO
plt.subplot(2, 3, 2)
plt.hist(df['DEFINITIVA_2P'], bins=10, color='skyblue')
#plt.title('Distribución de las Definitivas 2P')
#plt.xlabel('Definitiva (0->10)')
plt.ylabel('Frecuencia')

# Histograma DEFINITIVA DE TERCER PERIODO
plt.subplot(2, 3, 3)
plt.hist(df['DEFINITIVA_3P'], bins=10, color='skyblue')
#plt.title('Distribución de las Definitivas 1P')
#plt.xlabel('Definitiva (0->10)')
plt.ylabel('Frecuencia')

# Histograma DEFINITIVA DE CUARTO PERIODO
plt.subplot(2, 3, 4)
plt.hist(df['DEFINITIVA_4P'], bins=10, color='skyblue')
#plt.title('Distribución de las Definitivas 1P')
#plt.xlabel('Definitiva (0->10)')
plt.ylabel('Frecuencia')

# Histograma de la ASISTENCIA
plt.subplot(2, 3, 5)
plt.hist(df['ASISTENCIA'], bins=10, color='purple')
#plt.title('Distribución de Asistencia')
plt.ylabel('Frecuencia')
#plt.xlabel('Asistencia')


#ajustar espaciado entre subplot
plt.tight_layout()
plt.show()

# %% [markdown]
# **¿Cómo es la distribución de notas por curso?**

# %%
# @title **Gráfico de boxplot para ver la distribución de las notas por curso en 1P**
plt.figure(figsize=(30, 9))
sns.boxplot(x='CURSO', y='DEFINITIVA_1P', data=df)
plt.title('Distribución de Notas por Curso 1P')
plt.xlabel('Curso')
plt.ylabel('Nota Definitiva 1P')
plt.grid(True)
plt.show()

# %%
# @title **Gráfico de boxplot para ver la distribución de las notas por curso en 2P**
plt.figure(figsize=(30, 9))
sns.boxplot(x='CURSO', y='DEFINITIVA_2P', data=df)
plt.title('Distribución de Notas por Curso 2P')
plt.xlabel('Curso')
plt.ylabel('Nota Definitiva 2P')
plt.grid(True)
plt.show()

# %%
# @title **Gráfico de boxplot para ver la distribución de las notas por curso en 3P**
plt.figure(figsize=(30, 9))
sns.boxplot(x='CURSO', y='DEFINITIVA_3P', data=df)
plt.title('Distribución de Notas por Curso 3P')
plt.xlabel('Curso')
plt.ylabel('Nota Definitiva 3P')
plt.grid(True)
plt.show()

# %%
# @title **Gráfico de boxplot para ver la distribución de las notas por curso en 4P**
plt.figure(figsize=(30, 9))
sns.boxplot(x='CURSO', y='DEFINITIVA_4P', data=df)
plt.title('Distribución de Notas por Curso 4P')
plt.xlabel('Curso')
plt.ylabel('Nota Definitiva 4P')
plt.grid(True)
plt.show()

# %% [markdown]
# **Análisis**
#
# El gráfico de boxplot muestra la distribución de las notas por curso. Se puede observar cómo varían las notas entre los diferentes cursos, permitiendo identificar si hay diferencias significativas en el rendimiento de los estudiantes en cada uno. Las líneas centrales de cada boxplot representan la mediana de las notas, y los "bigotes" muestran el rango en el que se encuentran la mayoría de las calificaciones. Esto es útil para visualizar la dispersión y posibles valores atípicos en cada curso.

# %% [markdown]
# # **Relaciones entre variables**

# %% [markdown]
# **1. ¿Cuál es la correlación entre el hecho de que desyunen y duerman bien con las definitivas?**
#
# Se puede realizar un gráfico de dispersión y calcular el coeficiente de correlación. Primero con la definitiva de primer período

# %%
# Gráfico de dispersión para observar la relación entre el Desayuno con definitiva de primer período
plt.figure(figsize=(30, 6))
plt.scatter(df['COME BIEN'], df['DEFINITIVA_1P'], color='blue')
plt.title('Relación entre el come bien y la Definitiva 1P')
plt.xlabel('COME BIEN')
plt.ylabel('DEFINITIVA_1P')
plt.grid(True)
plt.show()

# %%
# Gráfico de dispersión para observar la relación entre el Desayuno con definitiva de segubdo período
plt.figure(figsize=(30, 9))
plt.scatter(df['COME BIEN'], df['DEFINITIVA_2P'], color='blue')
plt.title('Relación entre el come bien y la Definitiva 2P')
plt.xlabel('COME BIEN')
plt.ylabel('DEFINITIVA_2P')
plt.grid(True)
plt.show()

# %%
# Gráfico de dispersión para observar la relación entre el Desayuno con definitiva de tercer período
plt.figure(figsize=(30, 9))
plt.scatter(df['COME BIEN'], df['DEFINITIVA_3P'], color='blue')
plt.title('Relación entre el come bien y la Definitiva 3P')
plt.xlabel('COME BIEN')
plt.ylabel('DEFINITIVA_3P')
plt.grid(True)
plt.show()

# %%
# Gráfico de dispersión para observar la relación entre el Desayuno con definitiva de Cuarto período
plt.figure(figsize=(30, 9))
plt.scatter(df['COME BIEN'], df['DEFINITIVA_4P'], color='blue')
plt.title('Relación entre el come bien y la Definitiva 4P')
plt.xlabel('COME BIEN')
plt.ylabel('DEFINITIVA_4P')
plt.grid(True)
plt.show()

# %%
# Gráfico de dispersión para observar la relación entre el Descanso con definitiva de Primer período
plt.figure(figsize=(30, 9))
plt.scatter(df['DUERME BIEN'], df['DEFINITIVA_1P'], color='blue')
plt.title('Relación entre el descanso y la Definitiva 1P')
plt.xlabel('DUERME BIEN')
plt.ylabel('DEFINITIVA_1P')
plt.grid(True)
plt.show()

# %%
# Gráfico de dispersión para observar la relación entre el Descanso con definitiva de Segundo período
plt.figure(figsize=(30, 9))
plt.scatter(df['DUERME BIEN'], df['DEFINITIVA_2P'], color='blue')
plt.title('Relación entre el descanso y la Definitiva 2P')
plt.xlabel('DUERME BIEN')
plt.ylabel('DEFINITIVA_2P')
plt.grid(True)
plt.show()

# %%
# Gráfico de dispersión para observar la relación entre el Descanso con definitiva de Tercer período
plt.figure(figsize=(30, 9))
plt.scatter(df['DUERME BIEN'], df['DEFINITIVA_3P'], color='blue')
plt.title('Relación entre el descanso y la Definitiva 3P')
plt.xlabel('DUERME BIEN')
plt.ylabel('DEFINITIVA_3P')
plt.grid(True)
plt.show()

# %%
# Gráfico de dispersión para observar la relación entre el Descanso con definitiva de Cuarto período
plt.figure(figsize=(30, 9))
plt.scatter(df['DUERME BIEN'], df['DEFINITIVA_4P'], color='blue')
plt.title('Relación entre el descanso y la Definitiva 4P')
plt.xlabel('DUERME BIEN')
plt.ylabel('DEFINITIVA_4P')
plt.grid(True)
plt.show()

# %%
# Gráfico de dispersión para observar la relación entre el Desayuno y la asistencia a clases de los estudiantes
plt.figure(figsize=(30, 9))
plt.scatter(df['COME BIEN'], df['ASISTENCIA'], color='blue')
plt.title('Relación entre el come bien y la asistencia a clases')
plt.xlabel('COME BIEN')
plt.ylabel('ASISTENCIA')
plt.grid(True)
plt.show()

# %%
# Gráfico de dispersión para observar la relación entre el Descanso y la asistencia a clases de los estudiantes
plt.figure(figsize=(8, 6))
plt.scatter(df['DUERME BIEN'], df['ASISTENCIA'], color='blue')
plt.title('Relación entre el descanso y la asistencia a clases')
plt.xlabel('DUERME BIEN')
plt.ylabel('ASISTENCIA')
plt.grid(True)
plt.show()

# %% [markdown]
# **Análisis y conclusiones**
#
# Los gráficos de dispersión muestran claramente que los estudientes que no desayunan y/o no duermen bien tienen una menor asistencia a clases y, peor aun, un menor rendimiento académico. Por tanto se sugiere hacer los trámites ante la Secretaría de Educación Departamental para que también le provea el desyuno escolar a los estudiantes de grados superiores, puesto que, por el momento, solo le dan desayuno escolar a estudiantes de primaria y de sexto a noveno grado. Por otra parte, se sugiere hacer una campaña de concientizacíon con estudiantes y padres de familia para que se limite el uso de los dispositivos electrónicos, por parte de los estudiantes, para que puedan descansar lo sufiente.

# %% [markdown]
# **5. ¿Qué influencia tiene el transporte en la asistencia?**

# %%
# Gráfico de boxplot para ver la relación entre transporte y asistencia
plt.figure(figsize=(5, 4))
sns.boxplot(x='TRANSPORTE', y='ASISTENCIA', data=df)
plt.title('Relación entre Transporte y Asistencia')
plt.xlabel('Tipo de Transporte')
plt.ylabel('Asistencia')
plt.grid(True)
plt.xticks(rotation=45)
plt.show()

# Calcular la media de la asistencia por tipo de transporte
media_asistencia_transporte = df.groupby('TRANSPORTE')['ASISTENCIA'].mean()
media_asistencia_transporte
# Out:
# TRANSPORTE
# CAMINANDO    82.241379
# CARRO        86.029412
# MOTOTAXI     85.909091
# Name: ASISTENCIA, dtype: float64

# %% [markdown]
# El gráfico de boxplot muestra la relación entre el tipo de transporte utilizado por los estudiantes y su asistencia. Las medias de asistencia por tipo de transporte son las siguientes:
#
# - **Mototaxi:**63.8
# - **Caminando:** 61.9
# - **En Carro:** 49.0
# -
#
# **Análisis:** Los estudiantes que utilizan Mototaxi tienden a tener una asistencia ligeramente más alta en comparación con los que llegana a pie. Los que vienen en carro provienen de veredas y su asistencia es baja. Por tanto, se sugiere implementar una ruta de transporte escolar para estudiantes mas alejados.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# FIN
